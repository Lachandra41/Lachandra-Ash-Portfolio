# %%
'''
Adidas Vs. Nike Competitive Analysis
DSC680
Lachandra Ash
9/16/2022
'''
# Out:
# '\nAdidas Vs. Nike Competitive Analysis\nDSC680\nLachandra Ash\n9/16/2022\n'

# %%
#Import the neccessary libraries and modules
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#Import the Adidas vs Nike dataset into Pandas dataframe
df=pd.read_csv('Adidas Vs Nike.csv')
df
# Out:
#                                            Product_Name  Product_ID  \
# 0     Women's adidas Originals NMD_Racer Primeknit S...      AH2430
# 1                  Women's adidas Originals Sleek Shoes      G27341
# 2                     Women's adidas Swim Puka Slippers      CM0081
# 3      Women's adidas Sport Inspired Questar Ride Shoes      B44832
# 4              Women's adidas Originals Taekwondo Shoes      D98205
# ...                                                 ...         ...
# 3263                                 Air Jordan 8 Retro  CI1236-100
# 3264                         Nike Phantom Venom Club IC  AO0578-717
# 3265               Nike Mercurial Superfly 7 Academy TF  AT7978-414
# 3266                                    Nike Air Max 98  AH6799-300
# 3267                                     Nike P-6000 SE  CJ9585-600
#
#       Listing_Price  Sale_Price  Discount              Brand  \
# 0             14999        7499        50                  0
# ...

# %%
#Data Cleaning

# %%
#Display the first 5 records of the Adidas vs Nike dataset.
df.head(5)
# Out:
#                                         Product_Name Product_ID  \
# 0  Women's adidas Originals NMD_Racer Primeknit S...     AH2430
# 1               Women's adidas Originals Sleek Shoes     G27341
# 2                  Women's adidas Swim Puka Slippers     CM0081
# 3   Women's adidas Sport Inspired Questar Ride Shoes     B44832
# 4           Women's adidas Originals Taekwondo Shoes     D98205
#
#    Listing_Price  Sale_Price  Discount              Brand  \
# 0          14999        7499        50                  0
# 1           7599        3799        50   Adidas ORIGINALS
# 2            999         599        40  Adidas CORE / NEO
# 3           6999        3499        50  Adidas CORE / NEO
# 4           7999        3999        50   Adidas ORIGINALS
#
#                                          Description  Rating  Reviews  \
# 0  Channeling the streamlined look of an '80s rac...     4.8       41
# 1  A modern take on adidas sport heritage, tailor...     3.3       24
# ...

# %%
#Display the tail of the last five records. 
df.tail(5)
# Out:
#                               Product_Name  Product_ID  Listing_Price  \
# 3263                    Air Jordan 8 Retro  CI1236-100          15995
# 3264            Nike Phantom Venom Club IC  AO0578-717           4995
# 3265  Nike Mercurial Superfly 7 Academy TF  AT7978-414           8495
# 3266                       Nike Air Max 98  AH6799-300              0
# 3267                        Nike P-6000 SE  CJ9585-600           8995
#
#       Sale_Price  Discount Brand  \
# 3263       12797         0  Nike
# 3264        3497         0  Nike
# 3265        5947         0  Nike
# 3266       16995         0  Nike
# 3267        6297         0  Nike
#
#                                             Description  Rating  Reviews  \
# 3263  The Air Jordan 8 Retro recaptures the memorabl...     5.0        1
# 3264  The Nike Phantom Venom Club IC is engineered f...     0.0        0
# 3265  The soft upper of the Nike Mercurial Superfly ...     5.0        1
# ...

# %%
#Display the shape of the dataframe.
df.shape
# Out:
# (3268, 10)

# %%
#Display the index of the dataframe
df.index
# Out:
# RangeIndex(start=0, stop=3268, step=1)

# %%
#Display the columns within the dataframe.
df.columns
# Out:
# Index(['Product_Name', 'Product_ID', 'Listing_Price', 'Sale_Price', 'Discount',
#        'Brand', 'Description', 'Rating', 'Reviews', 'Last_Visited'],
#       dtype='object')

# %%
#Display the dataframe info.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3268 entries, 0 to 3267
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product_Name   3268 non-null   object
#  1   Product_ID     3268 non-null   object
#  2   Listing_Price  3268 non-null   int64
#  3   Sale_Price     3268 non-null   int64
#  4   Discount       3268 non-null   int64
#  5   Brand          3268 non-null   object
#  6   Description    3265 non-null   object
#  7   Rating         3268 non-null   float64
#  8   Reviews        3268 non-null   int64
#  9   Last_Visited   3268 non-null   object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 255.4+ KB

# %%
#Display the number of non-NA values within the dataframe.
df.count()
# Out:
# Product_Name     3268
# Product_ID       3268
# Listing_Price    3268
# Sale_Price       3268
# Discount         3268
# Brand            3268
# Description      3265
# Rating           3268
# Reviews          3268
# Last_Visited     3268
# dtype: int64

# %%
#Describe the dataframe.
df.describe()
# Out:
#        Listing_Price    Sale_Price     Discount       Rating      Reviews
# count    3268.000000   3268.000000  3268.000000  3268.000000  3268.000000
# mean     6868.020196   6134.265606    26.875765     3.242105    40.551714
# std      4724.659386   4293.247581    22.633487     1.428856    31.543491
# min         0.000000    449.000000     0.000000     0.000000     0.000000
# 25%      4299.000000   2999.000000     0.000000     2.600000    10.000000
# 50%      5999.000000   4799.000000    40.000000     3.500000    37.000000
# 75%      8999.000000   7995.000000    50.000000     4.400000    68.000000
# max     29999.000000  36500.000000    60.000000     5.000000   223.000000

# %%
#Display the number of null values within the dataframe.
df.isnull()
# Out:
#       Product_Name  Product_ID  Listing_Price  Sale_Price  Discount  Brand  \
# 0            False       False          False       False     False  False
# 1            False       False          False       False     False  False
# 2            False       False          False       False     False  False
# 3            False       False          False       False     False  False
# 4            False       False          False       False     False  False
# ...            ...         ...            ...         ...       ...    ...
# 3263         False       False          False       False     False  False
# 3264         False       False          False       False     False  False
# 3265         False       False          False       False     False  False
# 3266         False       False          False       False     False  False
# 3267         False       False          False       False     False  False
#
#       Description  Rating  Reviews  Last_Visited
# ...

# %%
#Display the sum of null values for each dataframe attribute.
df.isnull().sum()
# Out:
# Product_Name     0
# Product_ID       0
# Listing_Price    0
# Sale_Price       0
# Discount         0
# Brand            0
# Description      3
# Rating           0
# Reviews          0
# Last_Visited     0
# dtype: int64

# %%
#Display the number of values that are not null.
df.notnull()
# Out:
#       Product_Name  Product_ID  Listing_Price  Sale_Price  Discount  Brand  \
# 0             True        True           True        True      True   True
# 1             True        True           True        True      True   True
# 2             True        True           True        True      True   True
# 3             True        True           True        True      True   True
# 4             True        True           True        True      True   True
# ...            ...         ...            ...         ...       ...    ...
# 3263          True        True           True        True      True   True
# 3264          True        True           True        True      True   True
# 3265          True        True           True        True      True   True
# 3266          True        True           True        True      True   True
# 3267          True        True           True        True      True   True
#
#       Description  Rating  Reviews  Last_Visited
# ...

# %%
#Display the sum of values that are not null.
df.notnull().sum()
# Out:
# Product_Name     3268
# Product_ID       3268
# Listing_Price    3268
# Sale_Price       3268
# Discount         3268
# Brand            3268
# Description      3265
# Rating           3268
# Reviews          3268
# Last_Visited     3268
# dtype: int64

# %%
#Fill the null values in the Description column.
df["Description"].fillna("No Description", inplace = True)

# %%
#Display columns to check Description column for missing values.
df.isnull().sum()
# Out:
# Product_Name     0
# Product_ID       0
# Listing_Price    0
# Sale_Price       0
# Discount         0
# Brand            0
# Description      0
# Rating           0
# Reviews          0
# Last_Visited     0
# dtype: int64

# %%
#Display Product Name Value Counts.
df['Product_Name'].value_counts()
# Out:
# Women's adidas Originals Sambarose Shoes        16
# Men's adidas Originals Supercourt Shoes         16
# Men's adidas Originals Stan Smith Shoes         15
# Men's adidas Originals Continental 80 Shoes     14
# Nike Air Max 90                                 14
#                                                 ..
# Men's adidas Originals Superstar Clean Shoes     1
# Men's adidas Running Kivaro 1 shoes              1
# Men's adidas Originals Samba OG MS Shoes         1
# Men's adidas Sport Inspired Strikerr             1
# Nike P-6000 SE                                   1
# Name: Product_Name, Length: 1531, dtype: int64

# %%
#Display Product ID Value Counts.
df['Product_ID'].value_counts()
# Out:
# CD6720-808    3
# 414571-030    2
# AT5269-606    2
# AQ4176-049    2
# 553558-125    2
#              ..
# F35515        1
# F35615        1
# CK9466        1
# F36650        1
# CJ9585-600    1
# Name: Product_ID, Length: 3179, dtype: int64

# %%
#Display ListingS Price Value Counts.
df['Listing_Price'].value_counts()
# Out:
# 0       426
# 7999    331
# 5999    214
# 4999    185
# 5599    178
#        ...
# 7895      1
# 6495      1
# 4795      1
# 3995      1
# 9495      1
# Name: Listing_Price, Length: 78, dtype: int64

# %%
#Display Sale Price Value Counts.
df['Sale_Price'].value_counts()
# Out:
# 3999     159
# 2999     142
# 4799     105
# 2799     104
# 2499     103
#         ...
# 13495      1
# 14495      1
# 5295       1
# 3149       1
# 7597       1
# Name: Sale_Price, Length: 227, dtype: int64

# %%
#Display Discount Value Counts.
df['Discount'].value_counts()
# Out:
# 0     1302
# 50     994
# 40     763
# 30      99
# 60      61
# 20      49
# Name: Discount, dtype: int64

# %%
#Display Brand Value Counts.
df['Brand'].value_counts()
# Out:
# Adidas CORE / NEO           1111
# Adidas ORIGINALS             907
# Nike                         643
# Adidas SPORT PERFORMANCE     606
# 0                              1
# Name: Brand, dtype: int64

# %%
#Display Description Value Counts.
df['Description'].value_counts()
# Out:
# A well cushioned shoe with a fresher look that will appeal to young runners. Features Mesh upper for maximum ventilation, lightstrike IMEVA midsole with visible adiprene providing protection from harmful impact forces and durable Rubber outsole for long-lasting wear.                                        15
# Stylish and sleek adidas sandals for women are extremely lightweight. Adjustable straps enable optimal fit while the Synthetic upper and soft EVA footbed with fitted heel provide enhanced comfort. Rubber outsole with wet and dry traction pattern keeps you in control.                                        13
# Stylish and sleek adidas Hoist sandals for men. Adjustable straps enable optimal fit while the synthetic leather upper with embossing details for structure and style. The soft EVA footbed provide enhanced comfort. Durable and rugged rubber outsole with wet and dry traction pattern keeps you in control.    11
# ...

# %%
#Display Ratings Value Counts.
df['Rating'].value_counts()
# Out:
# 0.0    302
# 5.0    207
# 4.4    115
# 4.5    114
# 4.2    111
# 4.0    108
# 4.7    108
# 4.8    107
# 4.1    104
# 1.0    101
# 3.5    101
# 4.9     98
# 3.8     98
# 2.8     96
# 4.3     94
# 3.0     92
# 3.9     92
# 4.6     91
# 2.4     90
# 3.7     89
# 3.6     87
# 2.0     86
# 3.1     86
# 2.5     83
# 2.7     83
# 2.6     83
# 2.2     78
# 3.4     75
# 2.9     74
# 3.2     73
# 3.3     72
# 1.5     70
# Name: Rating, dtype: int64

# %%
#Display Reviews Value Counts.
df['Reviews'].value_counts()
# Out:
# 0      257
# 1      131
# 2       87
# 3       58
# 5       58
#       ...
# 99      19
# 55      15
# 60      14
# 223      1
# 105      1
# Name: Reviews, Length: 102, dtype: int64

# %%
#Display Lasted Visited Value Counts.
df['Last_Visited'].value_counts()
# Out:
# 2020-04-13T15:06:32    38
# 2020-04-13T15:06:28    38
# 2020-04-13T15:06:26    36
# 2020-04-13T15:06:35    34
# 2020-04-13T15:06:45    34
#                        ..
# 2020-04-13T15:35:01     1
# 2020-04-13T15:36:31     1
# 2020-04-13T15:36:39     1
# 2020-04-13T15:37:03     1
# 2020-04-13T15:42:57     1
# Name: Last_Visited, Length: 318, dtype: int64

# %%
#Display the correlation of the dataframe.
df.corr()
# Out:
#                Listing_Price  Sale_Price  Discount    Rating   Reviews
# Listing_Price       1.000000    0.312255  0.125999  0.099764  0.161296
# Sale_Price          0.312255    1.000000 -0.594659 -0.042172 -0.240728
# Discount            0.125999   -0.594659  1.000000  0.081510  0.313591
# Rating              0.099764   -0.042172  0.081510  1.000000  0.140577
# Reviews             0.161296   -0.240728  0.313591  0.140577  1.000000

# %%
#Display the covariance of the dataframe.
df.cov()
# Out:
#                Listing_Price    Sale_Price      Discount      Rating  \
# Listing_Price   2.232241e+07  6.333820e+06  13473.815794  673.491497
# Sale_Price      6.333820e+06  1.843197e+07 -57783.660289 -258.700596
# Discount        1.347382e+04 -5.778366e+04    512.274735    2.636025
# Rating          6.734915e+02 -2.587006e+02      2.636025    2.041630
# Reviews         2.403828e+04 -3.260034e+04    223.885214    6.335961
#
#                     Reviews
# Listing_Price  24038.279641
# Sale_Price    -32600.335442
# Discount         223.885214
# Rating             6.335961
# Reviews          994.991815

# %%
#Display the number of duplicates in the dataframe. 
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3263    False
# 3264    False
# 3265    False
# 3266    False
# 3267    False
# Length: 3268, dtype: bool

# %%
#Display the sum of duplicates within the dataframe. 
df.duplicated().sum()
# Out:
# 0

# %%
#Display the dtypes within the dataframe.
df.dtypes
# Out:
# Product_Name      object
# Product_ID        object
# Listing_Price      int64
# Sale_Price         int64
# Discount           int64
# Brand             object
# Description       object
# Rating           float64
# Reviews            int64
# Last_Visited      object
# dtype: object

# %%
#Use the lambda code to place the sale and listing prices in the correct format.
df[['Listing_Price', 'Sale_Price']]=df[['Listing_Price' , 'Sale_Price']].apply(lambda x: x/100)

# %%
#Display the dataframe after applying the lamba code.
df
# Out:
#                                            Product_Name  Product_ID  \
# 0     Women's adidas Originals NMD_Racer Primeknit S...      AH2430
# 1                  Women's adidas Originals Sleek Shoes      G27341
# 2                     Women's adidas Swim Puka Slippers      CM0081
# 3      Women's adidas Sport Inspired Questar Ride Shoes      B44832
# 4              Women's adidas Originals Taekwondo Shoes      D98205
# ...                                                 ...         ...
# 3263                                 Air Jordan 8 Retro  CI1236-100
# 3264                         Nike Phantom Venom Club IC  AO0578-717
# 3265               Nike Mercurial Superfly 7 Academy TF  AT7978-414
# 3266                                    Nike Air Max 98  AH6799-300
# 3267                                     Nike P-6000 SE  CJ9585-600
#
#       Listing_Price  Sale_Price  Discount              Brand  \
# 0            149.99       74.99        50                  0
# ...

# %%
#Exploratory Data Analysis

# %%
num_features = ['Listing_Price','Sale_Price', 'Discount', 'Rating', 'Reviews']

fig, axes = plt.subplots(2, 3,  figsize=(20, 10))
fig.suptitle('\nCummulative Density Plots - Numerical Features', fontsize=20)

counter = 0
for ii in range(2):
    for jj in range(3):
        if counter <5:
            sns.ecdfplot(ax=axes[ii, jj], data=df, x=num_features[counter])
        counter = counter+1

fig.tight_layout(pad=2.0)

# %%
#Display the brands and their listing prices.
fig, ax = plt.subplots(figsize = (12,6))
x = df['Listing_Price']
y = df['Brand']
plt.scatter(x,y)
plt.title('Brand vs Listing_Price')
plt.xlabel('Listing Price')
plt.ylabel('Brand')
# Out:
# Text(0, 0.5, 'Brand')

# %%
#Display the brands and their ratings.
fig, ax = plt.subplots(figsize = (12,6))
x = df['Brand']
y = df['Rating']
plt.bar(x,y)
plt.title('Brand vs Rating')
plt.xlabel('Brand')
plt.ylabel('Rating')
# Out:
# Text(0, 0.5, 'Rating')

# %%
#Plot the Brand's Sale Prices
plt.figure(figsize=(20, 10))
sns.distplot(df[df["Brand"]=="Adidas SPORT PERFORMANCE"].Listing_Price,kde=False,rug=False)
sns.distplot(df[df["Brand"]=="Nike"].Listing_Price,kde=False,rug=False)
sns.distplot(df[df["Brand"]=="Adidas ORIGINALS"].Listing_Price,kde=False,rug=False)
sns.distplot(df[df["Brand"]=="Adidas CORE / NEO"].Listing_Price,kde=False,rug=False)
plt.legend(labels=['Adidas SPORT PERFORMANCE','Nike','Adidas CORE / NEO','Adidas ORIGINALS'])
plt.show()

# %%
#Plot and display the Brands' Reviews
plt.figure(figsize=(20, 10))
sns.distplot(df[df["Brand"]=="Adidas CORE / NEO"].Reviews,kde=False,rug=False)
sns.distplot(df[df["Brand"]=="Adidas SPORT PERFORMANCE"].Reviews,kde=False,rug=False)
sns.distplot(df[df["Brand"]=="Nike"].Reviews,kde=False,rug=False)
sns.distplot(df[df["Brand"]=="Adidas ORIGINALS"].Reviews,kde=False,rug=False)
plt.legend(labels=['Nike','Adidas SPORT PERFORMANCE','Adidas ORIGINALS', 'Adidas CORE / NEO'])
plt.show()

# %%
#Plot the brands' consumer ratings.
plt.figure(figsize=(20, 10))
sns.distplot(df[df["Brand"]=="Nike"].Rating,kde=False,rug=False)
sns.distplot(df[df["Brand"]=="Adidas CORE / NEO"].Rating,kde=False,rug=False)
sns.distplot(df[df["Brand"]=="Adidas ORIGINALS"].Rating,kde=False,rug=False)
sns.distplot(df[df["Brand"]=="Adidas SPORT PERFORMANCE"].Rating,kde=False,rug=False)
plt.legend(labels=['Nike', 'Adidas CORE / NEO','Adidas ORIGINALS', 'Adidas SPORT PERFORMANCE'])
plt.show()

# %%
df_n0=df[(df['Listing_Price']==0)|(df['Brand']=='Nike')]
df_n0
# Out:
#                               Product_Name  Product_ID  Listing_Price  \
# 2625        Nike Air Force 1 '07 Essential  CJ1646-600           0.00
# 2626                  Nike Air Force 1 '07  CT4328-101           0.00
# 2627          Nike Air Force 1 Sage Low LX  CI3482-200           0.00
# 2628                   Nike Air Max Dia SE  CD0479-200           0.00
# 2629                   Nike Air Max Verona  CZ6156-101           0.00
# ...                                    ...         ...            ...
# 3263                    Air Jordan 8 Retro  CI1236-100         159.95
# 3264            Nike Phantom Venom Club IC  AO0578-717          49.95
# 3265  Nike Mercurial Superfly 7 Academy TF  AT7978-414          84.95
# 3266                       Nike Air Max 98  AH6799-300           0.00
# 3267                        Nike P-6000 SE  CJ9585-600          89.95
#
#       Sale_Price  Discount Brand  \
# 2625       74.95         0  Nike
# 2626       74.95         0  Nike
# ...

# %%
#Display pairplot od dataframe.
sns.pairplot(df_n0)

# %%
df1=df[['Listing_Price','Sale_Price','Discount','Brand','Rating','Reviews']]
df1
# Out:
#       Listing_Price  Sale_Price  Discount              Brand  Rating  Reviews
# 0            149.99       74.99        50                  0     4.8       41
# 1             75.99       37.99        50   Adidas ORIGINALS     3.3       24
# 2              9.99        5.99        40  Adidas CORE / NEO     2.6       37
# 3             69.99       34.99        50  Adidas CORE / NEO     4.1       35
# 4             79.99       39.99        50   Adidas ORIGINALS     3.5       72
# ...             ...         ...       ...                ...     ...      ...
# 3263         159.95      127.97         0               Nike     5.0        1
# 3264          49.95       34.97         0               Nike     0.0        0
# 3265          84.95       59.47         0               Nike     5.0        1
# 3266           0.00      169.95         0               Nike     4.0        4
# 3267          89.95       62.97         0               Nike     0.0        0
#
# [3268 rows x 6 columns]

# %%
df1=pd.get_dummies(df)
df1
# Out:
#       Listing_Price  Sale_Price  Discount  Rating  Reviews  \
# 0            149.99       74.99        50     4.8       41
# 1             75.99       37.99        50     3.3       24
# 2              9.99        5.99        40     2.6       37
# 3             69.99       34.99        50     4.1       35
# 4             79.99       39.99        50     3.5       72
# ...             ...         ...       ...     ...      ...
# 3263         159.95      127.97         0     5.0        1
# 3264          49.95       34.97         0     0.0        0
# 3265          84.95       59.47         0     5.0        1
# 3266           0.00      169.95         0     4.0        4
# 3267          89.95       62.97         0     0.0        0
#
#       Product_Name_Air Jordan 1 Jester XX Low Laced  \
# 0                                                 0
# 1                                                 0
# 2                                                 0
# ...

# %%
#Clustering

# %%
df2=df[['Listing_Price','Sale_Price','Discount','Brand','Rating','Reviews']]
df2=df2.replace({'Adidas ORIGINALS':1, 'Adidas CORE / NEO':2,'Adidas SPORT PERFORMANCE':3,'Nike':4})

# %%
df2
# Out:
#       Listing_Price  Sale_Price  Discount Brand  Rating  Reviews
# 0            149.99       74.99        50     0     4.8       41
# 1             75.99       37.99        50     1     3.3       24
# 2              9.99        5.99        40     2     2.6       37
# 3             69.99       34.99        50     2     4.1       35
# 4             79.99       39.99        50     1     3.5       72
# ...             ...         ...       ...   ...     ...      ...
# 3263         159.95      127.97         0     4     5.0        1
# 3264          49.95       34.97         0     4     0.0        0
# 3265          84.95       59.47         0     4     5.0        1
# 3266           0.00      169.95         0     4     4.0        4
# 3267          89.95       62.97         0     4     0.0        0
#
# [3268 rows x 6 columns]

# %%
from sklearn.cluster import KMeans
kmeans_model = KMeans(n_clusters=4, random_state=10).fit(df2)

# %%
labels = kmeans_model.labels_

# %%
color_codes = {0:'orange', 1:'green', 2:'black',3:'yellow'}
colors = [color_codes[x] for x in labels]

# %%
df['cluster']=pd.DataFrame(labels)

# %%
df_clus=df.groupby(['cluster','Brand'])['Product_ID'].count()
df_clus=df_clus.reset_index()

# %%
df['cluster']=pd.DataFrame(labels)
df_clus=df.groupby(['cluster','Brand'])['Product_ID'].count()
df_clus=df_clus.reset_index()

# %%
df_clus
# Out:
#     cluster                     Brand  Product_ID
# 0         0                         0           1
# 1         0          Adidas ORIGINALS         297
# 2         0  Adidas SPORT PERFORMANCE         208
# 3         0                      Nike         129
# 4         1         Adidas CORE / NEO         568
# 5         1          Adidas ORIGINALS         348
# 6         1  Adidas SPORT PERFORMANCE         222
# 7         1                      Nike           4
# 8         2                      Nike         401
# 9         3         Adidas CORE / NEO         543
# 10        3          Adidas ORIGINALS         262
# 11        3  Adidas SPORT PERFORMANCE         176
# 12        3                      Nike         109

# %%
plt.figure(figsize=(12, 12))
plt.legend(fontsize=10)
plt.tick_params(labelsize=10)
ax=sns.scatterplot(x=df['Brand'],y=df['Sale_Price'],hue=df['cluster'],size=df['Sale_Price'],data=df,sizes=(1,200))
ax.legend(loc='upper left',bbox_to_anchor=(1,1))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(12, 12))
plt.legend(fontsize=10)
plt.tick_params(labelsize=10)
ax=sns.scatterplot(x=df['Brand'],y=df['Rating'],hue=df['cluster'],size=df['Rating'],data=df,sizes=(1,200))
ax.legend(loc='upper left',bbox_to_anchor=(1,1))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df_sp200=df.sort_values(by='Sale_Price',ascending=False).head(200)

# %%
plt.figure(figsize=(12, 12))
plt.legend(fontsize=10)
plt.tick_params(labelsize=10)
ax=sns.scatterplot(x=df_sp200['Product_Name'],y=df_sp200['Sale_Price'],hue=df_sp200['cluster'],size=df_sp200['Sale_Price'],data=df_sp200,sizes=(1,200))
plt.xticks(rotation=90)
ax.legend(loc='upper left',bbox_to_anchor=(1,1))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(12, 12))
plt.legend(fontsize=10)
plt.tick_params(labelsize=10)
ax=sns.scatterplot(x=df_sp200['Product_Name'],y=df_sp200['Rating'],hue=df_sp200['cluster'],size=df_sp200['Rating'],data=df_sp200,sizes=(1,200))
plt.xticks(rotation=90)
ax.legend(loc='upper left',bbox_to_anchor=(1,1))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df_spt200=df.sort_values(by='Sale_Price',ascending=False).tail(200)

# %%
plt.figure(figsize=(12, 12))
plt.legend(fontsize=10)
plt.tick_params(labelsize=10)
ax=sns.scatterplot(x=df_spt200['Product_Name'],y=df_spt200['Sale_Price'],hue=df_spt200['cluster'],size=df_spt200['Sale_Price'],data=df_spt200,sizes=(1,200))
plt.xticks(rotation=90)
ax.legend(loc='upper left',bbox_to_anchor=(1,1))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(12, 12))
plt.legend(fontsize=10)
plt.tick_params(labelsize=10)
ax=sns.scatterplot(x=df_spt200['Product_Name'],y=df_spt200['Rating'],hue=df_spt200['cluster'],size=df_spt200['Rating'],data=df_spt200,sizes=(1,200))
plt.xticks(rotation=90)
ax.legend(loc='upper left',bbox_to_anchor=(1,1))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(12, 12))
plt.legend(fontsize=10)
plt.tick_params(labelsize=10)
ax=sns.scatterplot(x=df_spt200['Product_Name'],y=df_spt200['Rating'],hue=df_spt200['cluster'],size=df_spt200['Rating'],data=df_spt200,sizes=(1,200))
plt.xticks(rotation=90)
ax.legend(loc='upper left',bbox_to_anchor=(1,1))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
