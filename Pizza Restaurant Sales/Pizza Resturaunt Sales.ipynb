# %%
'''
Pizza Restaurant Sales Prediction
Lachandra Ash
11/15/2022
'''
# Out:
# '\nPizza Restaurant Sales Prediction\nLachandra Ash\n11/15/2022\n'

# %%
#Import the neccessary libraries and modules.
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import plotly
import plotly.express as px

# %%
#Import the adult csv dataset and display first five records.
df=pd.read_csv('Pizza Sales Prediction.csv')
df.head()
# Out:
#    order_details_id  order_id       pizza_id  quantity order_date order_time  \
# 0                 1         1     hawaiian_m         1   1/1/2015   11:38:36
# 1                 2         2  classic_dlx_m         1   1/1/2015   11:57:40
# 2                 3         2  five_cheese_l         1   1/1/2015   11:57:40
# 3                 4         2    ital_supr_l         1   1/1/2015   11:57:40
# 4                 5         2     mexicana_m         1   1/1/2015   11:57:40
#
#    unit_price  total_price pizza_size pizza_category  \
# 0       13.25        13.25          M        Classic
# 1       16.00        16.00          M        Classic
# 2       18.50        18.50          L         Veggie
# 3       20.75        20.75          L        Supreme
# 4       16.00        16.00          M         Veggie
#
#                                    pizza_ingredients  \
# 0           Sliced Ham, Pineapple, Mozzarella Cheese
# 1  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# ...

# %%
#Pre-Processing/Cleaning Pizza Sales Prediction Dataset

# %%
#Check dataframe for missing values.
df.isna()
# Out:
#        order_details_id  order_id  pizza_id  quantity  order_date  order_time  \
# 0                 False     False     False     False       False       False
# 1                 False     False     False     False       False       False
# 2                 False     False     False     False       False       False
# 3                 False     False     False     False       False       False
# 4                 False     False     False     False       False       False
# ...                 ...       ...       ...       ...         ...         ...
# 48615             False     False     False     False       False       False
# 48616             False     False     False     False       False       False
# 48617             False     False     False     False       False       False
# 48618             False     False     False     False       False       False
# 48619             False     False     False     False       False       False
#
# ...

# %%
#Count the the number of missing values in the dataframe.
df.isna().sum()
# Out:
# order_details_id     0
# order_id             0
# pizza_id             0
# quantity             0
# order_date           0
# order_time           0
# unit_price           0
# total_price          0
# pizza_size           0
# pizza_category       0
# pizza_ingredients    0
# pizza_name           0
# dtype: int64

# %%
# Exploratory Data Analysis

# %%
#Display the dataframe index.
df.index
# Out:
# RangeIndex(start=0, stop=48620, step=1)

# %%
#Display the dtypes of the dataset.
df.dtypes
# Out:
# order_details_id       int64
# order_id               int64
# pizza_id              object
# quantity               int64
# order_date            object
# order_time            object
# unit_price           float64
# total_price          float64
# pizza_size            object
# pizza_category        object
# pizza_ingredients     object
# pizza_name            object
# dtype: object

# %%
#Display the dataframe's information.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   order_details_id   48620 non-null  int64
#  1   order_id           48620 non-null  int64
#  2   pizza_id           48620 non-null  object
#  3   quantity           48620 non-null  int64
#  4   order_date         48620 non-null  object
#  5   order_time         48620 non-null  object
#  6   unit_price         48620 non-null  float64
#  7   total_price        48620 non-null  float64
#  8   pizza_size         48620 non-null  object
#  9   pizza_category     48620 non-null  object
#  10  pizza_ingredients  48620 non-null  object
#  11  pizza_name         48620 non-null  object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 4.5+ MB

# %%
#Display the dataframe's shape.
df.shape
# Out:
# (48620, 12)

# %%
#Describe the dataframe.
df.describe()
# Out:
#        order_details_id      order_id      quantity    unit_price  \
# count      48620.000000  48620.000000  48620.000000  48620.000000
# mean       24310.500000  10701.479761      1.019622     16.494132
# std        14035.529381   6180.119770      0.143077      3.621789
# min            1.000000      1.000000      1.000000      9.750000
# 25%        12155.750000   5337.000000      1.000000     12.750000
# 50%        24310.500000  10682.500000      1.000000     16.500000
# 75%        36465.250000  16100.000000      1.000000     20.250000
# max        48620.000000  21350.000000      4.000000     35.950000
#
#         total_price
# count  48620.000000
# mean      16.821474
# std        4.437398
# min        9.750000
# 25%       12.750000
# 50%       16.500000
# 75%       20.500000
# max       83.000000

# %%
#Display the sum of the dataframe
df.sum()
# Out:
# order_details_id                                            1181976510
# order_id                                                     520305946
# pizza_id             hawaiian_mclassic_dlx_mfive_cheese_lital_supr_...
# quantity                                                         49574
# order_date           1/1/20151/1/20151/1/20151/1/20151/1/20151/1/20...
# order_time           11:38:3611:57:4011:57:4011:57:4011:57:4011:57:...
# unit_price                                                    801944.7
# total_price                                                  817860.05
# pizza_size           MMLLMLMLMMSSSSSSLLSSLLSLLLLMLLSLMLSSLLSLSLLMLM...
# pizza_category       ClassicClassicVeggieSupremeVeggieChickenSuprem...
# pizza_ingredients    Sliced Ham, Pineapple, Mozzarella CheesePepper...
# pizza_name           The Hawaiian PizzaThe Classic Deluxe PizzaThe ...
# dtype: object

# %%
#Display the correlation of the dataframe
df.corr()
# Out:
#                   order_details_id  order_id  quantity  unit_price  \
# order_details_id          1.000000  0.999990  0.003639   -0.003286
# order_id                  0.999990  1.000000  0.003621   -0.003323
# quantity                  0.003639  0.003621  1.000000    0.007142
# unit_price               -0.003286 -0.003323  0.007142    1.000000
# total_price              -0.000847 -0.000889  0.541926    0.836087
#
#                   total_price
# order_details_id    -0.000847
# order_id            -0.000889
# quantity             0.541926
# unit_price           0.836087
# total_price          1.000000

# %%
#Display the covariance of the dataframe. 
df.cov()
# Out:
#                   order_details_id      order_id  quantity  unit_price  \
# order_details_id      1.969961e+08  8.674035e+07  7.306876 -167.021875
# order_id              8.674035e+07  3.819388e+07  3.201574  -74.385536
# quantity              7.306876e+00  3.201574e+00  0.020471    0.003701
# unit_price           -1.670219e+02 -7.438554e+01  0.003701   13.117357
# total_price          -5.274474e+01 -2.438351e+01  0.344063   13.437022
#
#                   total_price
# order_details_id   -52.744737
# order_id           -24.383509
# quantity             0.344063
# unit_price          13.437022
# total_price         19.690497

# %%
#Display the unique features of the dataframe.
df.nunique()
# Out:
# order_details_id     48620
# order_id             21350
# pizza_id                91
# quantity                 4
# order_date             358
# order_time           16382
# unit_price              25
# total_price             56
# pizza_size               5
# pizza_category           4
# pizza_ingredients       32
# pizza_name              32
# dtype: int64

# %%
#Display the unique categories of order details id.
df.order_details_id.unique()
# Out:
# array([    1,     2,     3, ..., 48618, 48619, 48620], dtype=int64)

# %%
#Display the unique categories of order id.
df.order_id.unique()
# Out:
# array([    1,     2,     3, ..., 21348, 21349, 21350], dtype=int64)

# %%
#Display the unique categories pizza_id.
df.pizza_id.unique()
# Out:
# array(['hawaiian_m', 'classic_dlx_m', 'five_cheese_l', 'ital_supr_l',
#        'mexicana_m', 'thai_ckn_l', 'ital_supr_m', 'prsc_argla_l',
#        'bbq_ckn_s', 'the_greek_s', 'spinach_supr_s', 'classic_dlx_s',
#        'green_garden_s', 'ital_cpcllo_l', 'ital_supr_s', 'mexicana_s',
#        'spicy_ital_l', 'spin_pesto_l', 'veggie_veg_s', 'mexicana_l',
#        'southw_ckn_l', 'bbq_ckn_l', 'cali_ckn_l', 'cali_ckn_m',
#        'pepperoni_l', 'cali_ckn_s', 'ckn_pesto_l', 'big_meat_s',
#        'soppressata_l', 'four_cheese_l', 'napolitana_s', 'calabrese_m',
#        'four_cheese_m', 'ital_veggie_s', 'mediterraneo_m',
#        'peppr_salami_s', 'spinach_fet_l', 'napolitana_l', 'sicilian_l',
#        'ital_cpcllo_m', 'southw_ckn_s', 'bbq_ckn_m', 'pepperoni_m',
#        'prsc_argla_s', 'sicilian_m', 'veggie_veg_l', 'ckn_alfredo_s',
#        'pepperoni_s', 'green_garden_l', 'green_garden_m', 'pep_msh_pep_l',
#        'hawaiian_s', 'peppr_salami_m', 'ckn_alfredo_m', 'peppr_salami_l',
# ...

# %%
#Display the unique categories pizza_id.
df.quantity.unique()
# Out:
# array([1, 2, 3, 4], dtype=int64)

# %%
#Display the unique categories pizza_id.
df.order_date.unique()
# Out:
# array(['1/1/2015', '1/2/2015', '1/3/2015', '1/4/2015', '1/5/2015',
#        '1/6/2015', '1/7/2015', '1/8/2015', '1/9/2015', '1/10/2015',
#        '1/11/2015', '1/12/2015', '1/13/2015', '1/14/2015', '1/15/2015',
#        '1/16/2015', '1/17/2015', '1/18/2015', '1/19/2015', '1/20/2015',
#        '1/21/2015', '1/22/2015', '1/23/2015', '1/24/2015', '1/25/2015',
#        '1/26/2015', '1/27/2015', '1/28/2015', '1/29/2015', '1/30/2015',
#        '1/31/2015', '2/1/2015', '2/2/2015', '2/3/2015', '2/4/2015',
#        '2/5/2015', '2/6/2015', '2/7/2015', '2/8/2015', '2/9/2015',
#        '2/10/2015', '2/11/2015', '2/12/2015', '2/13/2015', '2/14/2015',
#        '2/15/2015', '2/16/2015', '2/17/2015', '2/18/2015', '2/19/2015',
#        '2/20/2015', '2/21/2015', '2/22/2015', '2/23/2015', '2/24/2015',
#        '2/25/2015', '2/26/2015', '2/27/2015', '2/28/2015', '3/1/2015',
#        '3/2/2015', '3/3/2015', '3/4/2015', '3/5/2015', '3/6/2015',
# ...

# %%
#Display the unique categories pizza_id.
df.order_time.unique()
# Out:
# array(['11:38:36', '11:57:40', '12:12:28', ..., '20:51:07', '21:14:37',
#        '22:09:54'], dtype=object)

# %%
#Display the unique categories pizza_id.
df.unit_price.unique()
# Out:
# array([13.25, 16.  , 18.5 , 20.75, 16.5 , 12.75, 12.  , 12.5 , 20.5 ,
#        20.25, 16.75, 15.25, 17.95, 16.25, 14.75,  9.75, 17.5 , 10.5 ,
#        25.5 , 11.  , 14.5 , 12.25, 21.  , 23.65, 35.95])

# %%
#Display the unique categories pizza_id.
df.total_price.unique()
# Out:
# array([13.25, 16.  , 18.5 , 20.75, 16.5 , 12.75, 12.  , 12.5 , 20.5 ,
#        20.25, 16.75, 15.25, 17.95, 16.25, 14.75, 32.  ,  9.75, 17.5 ,
#        10.5 , 25.5 , 11.  , 14.5 , 12.25, 21.  , 62.25, 41.5 , 50.25,
#        23.65, 24.  , 33.5 , 35.9 , 25.  , 19.5 , 37.5 , 37.  , 41.  ,
#        33.  , 40.5 , 24.5 , 47.3 , 22.  , 35.95, 29.  , 29.5 , 26.5 ,
#        48.75, 32.5 , 30.5 , 48.  , 51.  , 36.  , 35.  , 83.  , 61.5 ,
#        49.5 , 55.5 ])

# %%
#Display the unique categories pizza_id.
df.pizza_size.unique()
# Out:
# array(['M', 'L', 'S', 'XL', 'XXL'], dtype=object)

# %%
#Display the unique categories pizza_id.
df.pizza_category.unique()
# Out:
# array(['Classic', 'Veggie', 'Supreme', 'Chicken'], dtype=object)

# %%
#Display the unique categories pizza_id.
df.pizza_ingredients.unique()
# Out:
# array(['Sliced Ham, Pineapple, Mozzarella Cheese',
#        'Pepperoni, Mushrooms, Red Onions, Red Peppers, Bacon',
#        'Mozzarella Cheese, Provolone Cheese, Smoked Gouda Cheese, Romano Cheese, Blue Cheese, Garlic',
#        'Calabrese Salami, Capocollo, Tomatoes, Red Onions, Green Olives, Garlic',
#        'Tomatoes, Red Peppers, Jalapeno Peppers, Red Onions, Cilantro, Corn, Chipotle Sauce, Garlic',
#        'Chicken, Pineapple, Tomatoes, Red Peppers, Thai Sweet Chilli Sauce',
#        'Prosciutto di San Daniele, Arugula, Mozzarella Cheese',
#        'Barbecued Chicken, Red Peppers, Green Peppers, Tomatoes, Red Onions, Barbecue Sauce',
#        'Kalamata Olives, Feta Cheese, Tomatoes, Garlic, Beef Chuck Roast, Red Onions',
#        'Spinach, Red Onions, Pepperoni, Tomatoes, Artichokes, Kalamata Olives, Garlic, Asiago Cheese',
#        'Spinach, Mushrooms, Tomatoes, Green Olives, Feta Cheese',
#        'Capocollo, Red Peppers, Tomatoes, Goat Cheese, Garlic, Oregano',
# ...

# %%
#Display the unique categories pizza_id.
df.pizza_name.unique()
# Out:
# array(['The Hawaiian Pizza', 'The Classic Deluxe Pizza',
#        'The Five Cheese Pizza', 'The Italian Supreme Pizza',
#        'The Mexicana Pizza', 'The Thai Chicken Pizza',
#        'The Prosciutto and Arugula Pizza', 'The Barbecue Chicken Pizza',
#        'The Greek Pizza', 'The Spinach Supreme Pizza',
#        'The Green Garden Pizza', 'The Italian Capocollo Pizza',
#        'The Spicy Italian Pizza', 'The Spinach Pesto Pizza',
#        'The Vegetables + Vegetables Pizza', 'The Southwest Chicken Pizza',
#        'The California Chicken Pizza', 'The Pepperoni Pizza',
#        'The Chicken Pesto Pizza', 'The Big Meat Pizza',
#        'The Soppressata Pizza', 'The Four Cheese Pizza',
#        'The Napolitana Pizza', 'The Calabrese Pizza',
#        'The Italian Vegetables Pizza', 'The Mediterranean Pizza',
#        'The Pepper Salami Pizza', 'The Spinach and Feta Pizza',
#        'The Sicilian Pizza', 'The Chicken Alfredo Pizza',
# ...

# %%
#Display the pizza category pizza name unique.
df.groupby("pizza_category")["pizza_name"].nunique()/df.pizza_name.nunique()
# Out:
# pizza_category
# Chicken    0.18750
# Classic    0.25000
# Supreme    0.28125
# Veggie     0.28125
# Name: pizza_name, dtype: float64

# %%
#Display the unit price mean.
df.unit_price.mean()
# Out:
# 16.494132044426006

# %%
#Group the pizza category unit price and use mean method.
df.groupby("pizza_category")["unit_price"].mean()
# Out:
# pizza_category
# Chicken    17.709408
# Classic    14.797490
# Supreme    17.363229
# Veggie     16.612639
# Name: unit_price, dtype: float64

# %%
#Group the pizza category by pizza size than use mean method.
df.groupby(["pizza_category", "pizza_size"])["unit_price"].mean()
# Out:
# pizza_category  pizza_size
# Chicken         L             20.750000
#                 M             16.750000
#                 S             12.750000
# Classic         L             18.376850
#                 M             14.739122
#                 S             11.375021
#                 XL            25.500000
#                 XXL           35.950000
# Supreme         L             20.652837
#                 M             16.429972
#                 S             14.048149
# Veggie          L             19.295383
#                 M             15.938485
#                 S             12.161352
# Name: unit_price, dtype: float64

# %%
#Display the value counts of the pizza name.
df["pizza_name"].value_counts(normalize=True)
# Out:
# The Classic Deluxe Pizza                      0.049691
# The Barbecue Chicken Pizza                    0.048787
# The Hawaiian Pizza                            0.048745
# The Pepperoni Pizza                           0.048725
# The Thai Chicken Pizza                        0.047614
# The California Chicken Pizza                  0.047347
# The Sicilian Pizza                            0.038811
# The Spicy Italian Pizza                       0.038811
# The Southwest Chicken Pizza                   0.038770
# The Four Cheese Pizza                         0.038050
# The Italian Supreme Pizza                     0.038030
# The Big Meat Pizza                            0.037248
# The Vegetables + Vegetables Pizza             0.031057
# The Mexicana Pizza                            0.029947
# The Napolitana Pizza                          0.029844
# The Spinach and Feta Pizza                    0.029453
# The Prosciutto and Arugula Pizza              0.029371
# ...

# %%
#Display pizza size and pizza category along with the unit price and apply mean method.
df[(df.pizza_size == "S") & (df.pizza_category == "Classic")]["unit_price"].mean()
# Out:
# 11.375020920502092

# %%
#Display the pizza size, total price, and sum.
df[df.pizza_size == "XXL"]["total_price"].sum()/ df["total_price"].sum()
# Out:
# 0.0012307729176892798

# %%
#Display the pizza size, total price, and sum.
df[(df.pizza_size == "XL") | (df.pizza_size == "XXL")]["total_price"].sum()/ df["total_price"].sum()
# Out:
# 0.018441541434870184

# %%
#Display and group the order date and pizza name count, and sort the values.
df.groupby("order_date")["pizza_name"].count().sort_values(ascending = False).head(10)
# Out:
# order_date
# 11/26/2015    261
# 11/27/2015    259
# 10/15/2015    258
# 7/4/2015      233
# 7/3/2015      207
# 5/15/2015     205
# 10/1/2015     190
# 2/1/2015      188
# 7/24/2015     188
# 8/14/2015     185
# Name: pizza_name, dtype: int64

# %%
#Append order time values.
order_time= []
for i in range(len(df)): 
    order_time.append(df["order_time"].values[i])

# %%
#Define the order time.
df["order_time"] = order_time

# %%
#Group orders by time and id, then use the count method.
orders_by_time = pd.DataFrame(df.groupby(["order_time", "order_id"])["pizza_name"].count())

# %%
#Display the order time of the pizza name and count.
orders_by_time.groupby("order_time")["pizza_name"].count()
# Out:
# order_time
# 10:25:19    1
# 10:34:34    1
# 10:43:04    1
# 10:50:46    1
# 10:52:26    1
#            ..
# 23:05:16    1
# 23:05:17    1
# 23:05:24    1
# 23:05:52    1
# 9:52:21     1
# Name: pizza_name, Length: 16382, dtype: int64

# %%
#Display the data of order id and group it by total price. Use mean method.
df.groupby("order_id")["total_price"].sum().mean()
# Out:
# 38.30726229508162

# %%
#Group the order id by total price, and add the features together. 
df.groupby("order_id")["total_price"].sum().max()
# Out:
# 444.2

# %%
#Group the order id and total price, then use sum and min methods.
df.groupby("order_id")["total_price"].sum().min()
# Out:
# 9.75

# %%
#Define pizza orders prices.
Pizza_orders_prices = df.groupby("order_id")["total_price"].sum()

# %%
#Display the count of pizza orders prices.
Pizza_orders_prices[Pizza_orders_prices < 25].count()
# Out:
# 8441

# %%
#Display the count of the pizza order prices that are less than 25 and greater than 50.
Pizza_orders_prices[(Pizza_orders_prices > 25) & (Pizza_orders_prices < 50)].count()
# Out:
# 7615

# %%
#Display the count of pizza order prices that are greater than 50.
Pizza_orders_prices[Pizza_orders_prices > 50].count()
# Out:
# 5204

# %%
#Display the count of pizza order prices that are less than 50 and divide it by pizza order prices.
Pizza_orders_prices[Pizza_orders_prices < 50].count()/len(Pizza_orders_prices)
# Out:
# 0.7540983606557377

# %%
#Display the sum of the pizza orders prices less than 50 and divide it by the pizza order prices sum.
Pizza_orders_prices[Pizza_orders_prices < 50].sum()/Pizza_orders_prices.sum()
# Out:
# 0.5129300544757016

# %%
#Display the sum of the pizza order prices that are greater than fifty and divide it by pizza order prices sum.
Pizza_orders_prices[Pizza_orders_prices > 50].sum()/Pizza_orders_prices.sum()
# Out:
# 0.4842577284463278

# %%
#Data Visualization

# %%
#Display the quantity of pizzas.
sns.countplot(df['quantity'])
plt.title('The Quantity of Pizzas')         
plt.show()

# %%
#Display the number of pizzas per pizza category and size.
sns.histplot(df, x= "pizza_category", hue = "pizza_size")
plt.title("Number of Pizzas Ordered by Pizza Category and Size", fontsize = 15)
plt.show()

# %%
#Display the numbers of pizzas ordered by size.
sns.histplot(df, x = "pizza_size", palette = "bright")
plt.title("Number of Pizzas Ordered by Size", fontsize = 15)
plt.show()

# %%
#Display the number of pizzas ordered per total price.
sns.histplot(df, x = "total_price")
plt.title("Number of Pizza Ordered Per Total Price", fontsize = 15)
plt.show()

# %%
#Display the numbers of pizzas ordered per unit price.
sns.histplot(df, x = "unit_price", palette = "bright")
plt.title("Unit Price Per Pizza", fontsize = 15)
plt.show()

# %%
#Display the number of pizzas ordered by name.
sns.histplot(df, x = "pizza_name", palette = "bright")
plt.title("The Pizza's Name and Number of Pizzas Ordered", fontsize = 15)
plt.xticks(rotation = 90)
plt.show()

# %%
#Plot the scatter of total price and pizza category.
plt.scatter(df.pizza_category,df.total_price)
plt.xlabel('Pizza Category')
plt.ylabel('Total Price')
plt.title('Pizza Category and Total Price')
plt.show()

# %%
#Plot the scatter of total price and pizza name.
plt.scatter(df.pizza_name,df.total_price)
plt.xlabel('Pizza Name')
plt.ylabel('Total Price')
plt.title('Pizza Name and Total Price')
plt.xticks(rotation = 90)
plt.show()

# %%
#Plot the scatter of vehicle type and price in thousands.
plt.scatter(df.quantity,df.total_price)
plt.xlabel('Quantity of Pizza')
plt.ylabel('Total Price')
plt.title('Quantity of Pizza and Total Price')
plt.show()

# %%
#Plot the scatter of unit price and pizza name.
plt.scatter(df.pizza_name,df.unit_price)
plt.xlabel('Pizza Name')
plt.ylabel('Unit Price')
plt.title('Unit Price of Each Type of Pizza')
plt.xticks(rotation = 90)
plt.show()

# %%
#Display the pairplot of the df dataframe.
sns.pairplot(df)
